# %%
# !which python
# !which pip
# !which fastapi
# Out:
# /Users/zakerhussainrasooli/FreeProjects/searchintel-ai/backend/.venv/bin/python
# /Users/zakerhussainrasooli/FreeProjects/searchintel-ai/backend/.venv/bin/pip
# /Users/zakerhussainrasooli/FreeProjects/searchintel-ai/backend/.venv/bin/fastapi

# %%
# !hash -r

# %%
# !python -m ruff check app tests scripts --fix

# %%
# !python -m ruff check app tests scripts

# %%
# !alembic upgrade head

# %%
# !python -m ruff format app/core/config.py
# !python -m ruff check app/core/config.py

# %% [markdown]
# ## ======= Servers Runner Part =======

# %%
# =======  =======

# !fastapi dev app/main.py

# %%
#======== BackEnd Server run FastAPI=======

# !uvicorn app.main:app --reload
# !python -m uvicorn app.main:app --reload

# %%
# ======== Docker PostgreSQL    * Starter *.    =======

# !docker start cxops-postgres

# %%
# ======== Docker Run Tests =======

# !docker compose up -d
# !docker compose ps

# %%
# !npm run dev

# %% [markdown]
# ## ======= Git Commiting Part =======

# %%
# !git status --short

# !git remote -v

# %%
# !git add -A
# !git status

# %%
# !git commit -m "chore: clarify historical queue reliability metrics"
# !git push 
# !git push origin main
# !git status

# %%
# !git diff --check
